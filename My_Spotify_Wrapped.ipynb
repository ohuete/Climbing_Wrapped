# %%
# pip install spotipy

# %%
pip install gspread
# Out:
# ...
#      |████████████████████████████████| 40 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 177 kB 3.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 151 kB 21.7 MB/s eta 0:00:01
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.33.0
#     Uninstalling google-auth-1.33.0:
#       Successfully uninstalled google-auth-1.33.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-storage 1.31.0 requires google-auth<2.0dev,>=1.11.0, but you have google-auth 2.16.0 which is incompatible.
# google-cloud-core 1.7.1 requires google-auth<2.0dev,>=1.24.0, but you have google-auth 2.16.0 which is incompatible.
# google-api-core 1.25.1 requires google-auth<2.0dev,>=1.21.1, but you have google-auth 2.16.0 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime
import gspread

# %%
SPOTIPY_CLIENT_ID = 'f90efb9e78574dd49b813de1efa3232d'
SPOTIPY_CLIENT_SECRET = '9fe92f01ad174875ad43cfb4e3ee6120'
SPOTIPY_REDIRECT_URI = 'http://127.0.0.1:9090'
SCOPE = "user-top-read"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID,
                                               client_secret=SPOTIPY_CLIENT_SECRET,
                                               redirect_uri=SPOTIPY_REDIRECT_URI,
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20, offset=0, time_range="short_term")

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
# ...

# %%
type(top_tracks_short)
# Out:
# dict

# %%
def get_track_ids(time_frame):
    track_ids = []
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids = get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['3OHfY25tqY28d16oZczHc8',
#  '6Sq7ltF9Qa7SNFBsV5Cogx',
#  '465JohWeaz2FKbdKVmXvrJ',
#  '2RS2WLUJAl6lWZ2R6kb0Zv',
#  '3qurp3IMuJX3Ucr3OCDUg5',
#  '1SC5rEoYDGUK4NfG82494W',
#  '2GAhgAjOhEmItWLfgisyOn',
#  '480rD34KfGbMaT0L6zjeIu',
#  '48byBopt3UYEymfD8NoCuI',
#  '52ojopYMUzeNcudsoz7O9D',
#  '6eT2V7nKXyMf47TwPbtgAD',
#  '5b5AGYvoznaNnbyIqs2DcH',
#  '27fLVVpBdd3lyvbrbq5hHM',
#  '4alOnaeYVupWNmfRqdOm29',
#  '556jf0hyPQuLNHuNWo12I5',
#  '1eIXYZWEfJO3Na2LCCnIJE',
#  '2CSRrnOEELmhpq8iaAi9cd',
#  '1TweDM3JC49LNeelLVg3yX',
#  '2l7JlYeniNFfIzfj3dOUjb',
#  '4PMqSO5qyjpvzhlLI5GnID']

# %%
track_id = '3OHfY25tqY28d16oZczHc8'

# %%
def get_track_features(id):
    meta = sp.track(id)
    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info = [name, album, artist, spotify_url, album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Kill Bill',
#  'SOS',
#  'SZA',
#  'https://open.spotify.com/track/3OHfY25tqY28d16oZczHc8',
#  'https://i.scdn.co/image/ab67616d0000b27370dbc9f47669d120ad874ec1']

# %%
# loop over track ids 
tracks = []
for i in range(len(track_ids)):
    time.sleep(.5)
    track = get_track_features(track_ids[i])
    tracks.append(track)

# %%
tracks
# Out:
# [['Kill Bill',
#   'SOS',
#   'SZA',
#   'https://open.spotify.com/track/3OHfY25tqY28d16oZczHc8',
#   'https://i.scdn.co/image/ab67616d0000b27370dbc9f47669d120ad874ec1'],
#  ['Me Porto Bonito',
#   'Un Verano Sin Ti',
#   'Bad Bunny',
#   'https://open.spotify.com/track/6Sq7ltF9Qa7SNFBsV5Cogx',
#   'https://i.scdn.co/image/ab67616d0000b27349d694203245f241a1bcaa72'],
#  ['Voodoo',
#   'Yellow Moon',
#   'The Neville Brothers',
#   'https://open.spotify.com/track/465JohWeaz2FKbdKVmXvrJ',
#   'https://i.scdn.co/image/ab67616d0000b273f509a08a3e14a916298512a9'],
#  ['Sweet Honey Dripper',
#   'Fiyo On The Bayou',
#   'The Neville Brothers',
#   'https://open.spotify.com/track/2RS2WLUJAl6lWZ2R6kb0Zv',
#   'https://i.scdn.co/image/ab67616d0000b273bc85815182a0877b04310ad0'],
#  ['Is It Boy - Demo',
#   'Old Dog Demos',
#   'Mac DeMarco',
#   'https://open.spotify.com/track/3qurp3IMuJX3Ucr3OCDUg5',
#   'https://i.scdn.co/image/ab67616d0000b27306bcba8c72327edfdf89583f'],
# ...

# %%
# create dataset
df = pd.DataFrame(tracks, columns = ["name", "album", "artist", "spotify_url", "album_cover"])
df.head(5)
# Out:
#                   name              album                artist  \
# 0            Kill Bill                SOS                   SZA
# 1      Me Porto Bonito   Un Verano Sin Ti             Bad Bunny
# 2               Voodoo        Yellow Moon  The Neville Brothers
# 3  Sweet Honey Dripper  Fiyo On The Bayou  The Neville Brothers
# 4     Is It Boy - Demo      Old Dog Demos           Mac DeMarco
#
#                                          spotify_url  \
# 0  https://open.spotify.com/track/3OHfY25tqY28d16...
# 1  https://open.spotify.com/track/6Sq7ltF9Qa7SNFB...
# 2  https://open.spotify.com/track/465JohWeaz2FKbd...
# 3  https://open.spotify.com/track/2RS2WLUJAl6lWZ2...
# 4  https://open.spotify.com/track/3qurp3IMuJX3Ucr...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b27370dbc9...
# 1  https://i.scdn.co/image/ab67616d0000b27349d694...
# 2  https://i.scdn.co/image/ab67616d0000b273f509a0...
# ...
