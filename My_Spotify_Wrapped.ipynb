# %%
# pip install spotipy

# %%
# pip install gspread

# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime
import gspread

# %%
SPOTIPY_CLIENT_ID = 'f90efb9e78574dd49b813de1efa3232d'
SPOTIPY_CLIENT_SECRET = '9fe92f01ad174875ad43cfb4e3ee6120'
SPOTIPY_REDIRECT_URI = 'http://127.0.0.1:9090'
SCOPE = "user-top-read"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=SPOTIPY_CLIENT_ID,
                                               client_secret=SPOTIPY_CLIENT_SECRET,
                                               redirect_uri=SPOTIPY_REDIRECT_URI,
                                               scope=SCOPE))

# %%
top_tracks_short = sp.current_user_top_tracks(limit=20, offset=0, time_range="short_term")

# %%
top_tracks_short
# Out:
# {'items': [{'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6bR0cgMtkCVpm0I5yrDNzO'},
#       'href': 'https://api.spotify.com/v1/artists/6bR0cgMtkCVpm0I5yrDNzO',
#       'id': '6bR0cgMtkCVpm0I5yrDNzO',
#       'name': 'Big Mama Thornton',
#       'type': 'artist',
#       'uri': 'spotify:artist:6bR0cgMtkCVpm0I5yrDNzO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6U60FpmscwzTJjc9gmZcKl'},
#     'href': 'https://api.spotify.com/v1/albums/6U60FpmscwzTJjc9gmZcKl',
#     'id': '6U60FpmscwzTJjc9gmZcKl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f25345e400eb77c2d49f8558',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f25345e400eb77c2d49f8558',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f25345e400eb77c2d49f8558',
#       'width': 64}],
#     'name': "Ball n' Chain",
#     'release_date': '1989-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:6U60FpmscwzTJjc9gmZcKl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6bR0cgMtkCVpm0I5yrDNzO'},
#      'href': 'https://api.spotify.com/v1/artists/6bR0cgMtkCVpm0I5yrDNzO',
#      'id': '6bR0cgMtkCVpm0I5yrDNzO',
#      'name': 'Big Mama Thornton',
#      'type': 'artist',
#      'uri': 'spotify:artist:6bR0cgMtkCVpm0I5yrDNzO'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 181000,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAP38930505'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5Oc0vLGWdEWeCqIU8zyELt'},
#    'href': 'https://api.spotify.com/v1/tracks/5Oc0vLGWdEWeCqIU8zyELt',
#    'id': '5Oc0vLGWdEWeCqIU8zyELt',
#    'is_local': False,
#    'name': 'Hound Dog',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/40ae27dfbd38ea748c606dae1b93f0d598bd5290?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5Oc0vLGWdEWeCqIU8zyELt'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#       'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#       'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#       'name': 'Mac DeMarco',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2sij95QgjmgrhNv33achzn'},
#     'href': 'https://api.spotify.com/v1/albums/2sij95QgjmgrhNv33achzn',
#     'id': '2sij95QgjmgrhNv33achzn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ec6e9c13eeed14eedbd5f7c9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ec6e9c13eeed14eedbd5f7c9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ec6e9c13eeed14eedbd5f7c9',
#       'width': 64}],
#     'name': 'Salad Days',
#     'release_date': '2014-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2sij95QgjmgrhNv33achzn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#      'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#      'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#      'name': 'Mac DeMarco',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 179766,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMMZN1300564'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7veyzFpXGgZj5Ul3TZ1lBc'},
#    'href': 'https://api.spotify.com/v1/tracks/7veyzFpXGgZj5Ul3TZ1lBc',
#    'id': '7veyzFpXGgZj5Ul3TZ1lBc',
#    'is_local': False,
#    'name': 'Goodbye Weekend',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3cfee18244b14383270424c81b98426f58f256db?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7veyzFpXGgZj5Ul3TZ1lBc'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#       'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#       'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#       'name': 'Mac DeMarco',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3oMrhnFjxkH6ccmXE4ltVn'},
#     'href': 'https://api.spotify.com/v1/albums/3oMrhnFjxkH6ccmXE4ltVn',
#     'id': '3oMrhnFjxkH6ccmXE4ltVn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27306bcba8c72327edfdf89583f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0206bcba8c72327edfdf89583f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485106bcba8c72327edfdf89583f',
#       'width': 64}],
#     'name': 'Old Dog Demos',
#     'release_date': '2018-04-21',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3oMrhnFjxkH6ccmXE4ltVn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#      'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#      'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#      'name': 'Mac DeMarco',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 230277,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMMZN1801589'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3qurp3IMuJX3Ucr3OCDUg5'},
#    'href': 'https://api.spotify.com/v1/tracks/3qurp3IMuJX3Ucr3OCDUg5',
#    'id': '3qurp3IMuJX3Ucr3OCDUg5',
#    'is_local': False,
#    'name': 'Is It Boy - Demo',
#    'popularity': 32,
#    'preview_url': 'https://p.scdn.co/mp3-preview/904f45954b8a42f9143bb5adf75cbe3cc5c27758?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3qurp3IMuJX3Ucr3OCDUg5'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QwBhFIOXWri9BNtwoIlKY'},
#       'href': 'https://api.spotify.com/v1/artists/6QwBhFIOXWri9BNtwoIlKY',
#       'id': '6QwBhFIOXWri9BNtwoIlKY',
#       'name': 'Bernadette Carroll',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QwBhFIOXWri9BNtwoIlKY'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0TmAzg18PYIzVXuJfPmaIL'},
#     'href': 'https://api.spotify.com/v1/albums/0TmAzg18PYIzVXuJfPmaIL',
#     'id': '0TmAzg18PYIzVXuJfPmaIL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d0c6e9667b128a9801e5e2c8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d0c6e9667b128a9801e5e2c8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d0c6e9667b128a9801e5e2c8',
#       'width': 64}],
#     'name': 'Laughing On The Outside',
#     'release_date': '2021-04-16',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:0TmAzg18PYIzVXuJfPmaIL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6QwBhFIOXWri9BNtwoIlKY'},
#      'href': 'https://api.spotify.com/v1/artists/6QwBhFIOXWri9BNtwoIlKY',
#      'id': '6QwBhFIOXWri9BNtwoIlKY',
#      'name': 'Bernadette Carroll',
#      'type': 'artist',
#      'uri': 'spotify:artist:6QwBhFIOXWri9BNtwoIlKY'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 116622,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCW62144904'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2fDkRzOciUWQPnIhW6CsHy'},
#    'href': 'https://api.spotify.com/v1/tracks/2fDkRzOciUWQPnIhW6CsHy',
#    'id': '2fDkRzOciUWQPnIhW6CsHy',
#    'is_local': False,
#    'name': 'Sweet Sugar Sweet',
#    'popularity': 13,
#    'preview_url': 'https://p.scdn.co/mp3-preview/35c89eb68312bf2abc9418563793fe0dd2bb27b2?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2fDkRzOciUWQPnIhW6CsHy'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#       'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#       'id': '5INjqkS1o8h1imAzPqGZBb',
#       'name': 'Tame Impala',
#       'type': 'artist',
#       'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/79dL7FLiJFOO0EoehUHQBv'},
#     'href': 'https://api.spotify.com/v1/albums/79dL7FLiJFOO0EoehUHQBv',
#     'id': '79dL7FLiJFOO0EoehUHQBv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739e1cfc756886ac782e363d79',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029e1cfc756886ac782e363d79',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519e1cfc756886ac782e363d79',
#       'width': 64}],
#     'name': 'Currents',
#     'release_date': '2015-07-17',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:79dL7FLiJFOO0EoehUHQBv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5INjqkS1o8h1imAzPqGZBb'},
#      'href': 'https://api.spotify.com/v1/artists/5INjqkS1o8h1imAzPqGZBb',
#      'id': '5INjqkS1o8h1imAzPqGZBb',
#      'name': 'Tame Impala',
#      'type': 'artist',
#      'uri': 'spotify:artist:5INjqkS1o8h1imAzPqGZBb'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 107533,
#    'explicit': False,
#    'external_ids': {'isrc': 'AUUM71500293'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1cCbsojaA6GIT7Y3zuMJ1q'},
#    'href': 'https://api.spotify.com/v1/tracks/1cCbsojaA6GIT7Y3zuMJ1q',
#    'id': '1cCbsojaA6GIT7Y3zuMJ1q',
#    'is_local': False,
#    'name': 'Nangs',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/efd526cddbe83a0435ba7fb72c111d9549d087dc?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1cCbsojaA6GIT7Y3zuMJ1q'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41Nu7NgAj9rJxjj7JDuXrV'},
#       'href': 'https://api.spotify.com/v1/artists/41Nu7NgAj9rJxjj7JDuXrV',
#       'id': '41Nu7NgAj9rJxjj7JDuXrV',
#       'name': 'Peter Cat Recording Co.',
#       'type': 'artist',
#       'uri': 'spotify:artist:41Nu7NgAj9rJxjj7JDuXrV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6gnNCtxxhwKTYGIDVqeMUd'},
#     'href': 'https://api.spotify.com/v1/albums/6gnNCtxxhwKTYGIDVqeMUd',
#     'id': '6gnNCtxxhwKTYGIDVqeMUd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27319497200ef054bccfab27d0c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0219497200ef054bccfab27d0c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485119497200ef054bccfab27d0c',
#       'width': 64}],
#     'name': 'Bismillah',
#     'release_date': '2019-06-07',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6gnNCtxxhwKTYGIDVqeMUd'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41Nu7NgAj9rJxjj7JDuXrV'},
#      'href': 'https://api.spotify.com/v1/artists/41Nu7NgAj9rJxjj7JDuXrV',
#      'id': '41Nu7NgAj9rJxjj7JDuXrV',
#      'name': 'Peter Cat Recording Co.',
#      'type': 'artist',
#      'uri': 'spotify:artist:41Nu7NgAj9rJxjj7JDuXrV'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 256000,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR9W11829841'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/556jf0hyPQuLNHuNWo12I5'},
#    'href': 'https://api.spotify.com/v1/tracks/556jf0hyPQuLNHuNWo12I5',
#    'id': '556jf0hyPQuLNHuNWo12I5',
#    'is_local': False,
#    'name': 'Floated By',
#    'popularity': 47,
#    'preview_url': 'https://p.scdn.co/mp3-preview/28bbb6e4bc2bf722c8c8c4bfe7a5411960710f50?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:556jf0hyPQuLNHuNWo12I5'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12fRkVfO2fUsz1QHgDAG3g'},
#       'href': 'https://api.spotify.com/v1/artists/12fRkVfO2fUsz1QHgDAG3g',
#       'id': '12fRkVfO2fUsz1QHgDAG3g',
#       'name': 'Julia Jacklin',
#       'type': 'artist',
#       'uri': 'spotify:artist:12fRkVfO2fUsz1QHgDAG3g'}],
#     'available_markets': ['CR',
#      'DO',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'SV',
#      'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/50G6NiGQgtYNiwNK018q8v'},
#     'href': 'https://api.spotify.com/v1/albums/50G6NiGQgtYNiwNK018q8v',
#     'id': '50G6NiGQgtYNiwNK018q8v',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e17d7a15cf864f9920271304',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e17d7a15cf864f9920271304',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e17d7a15cf864f9920271304',
#       'width': 64}],
#     'name': 'Crushing',
#     'release_date': '2019-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:50G6NiGQgtYNiwNK018q8v'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12fRkVfO2fUsz1QHgDAG3g'},
#      'href': 'https://api.spotify.com/v1/artists/12fRkVfO2fUsz1QHgDAG3g',
#      'id': '12fRkVfO2fUsz1QHgDAG3g',
#      'name': 'Julia Jacklin',
#      'type': 'artist',
#      'uri': 'spotify:artist:12fRkVfO2fUsz1QHgDAG3g'}],
#    'available_markets': ['CR', 'DO', 'GT', 'HN', 'MX', 'NI', 'PA', 'SV', 'US'],
#    'disc_number': 1,
#    'duration_ms': 182306,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKZV1800117'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/480rD34KfGbMaT0L6zjeIu'},
#    'href': 'https://api.spotify.com/v1/tracks/480rD34KfGbMaT0L6zjeIu',
#    'id': '480rD34KfGbMaT0L6zjeIu',
#    'is_local': False,
#    'name': 'Pressure To Party',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7d4df3d6555fa548eb7e3a56c8fc0acf89467d31?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:480rD34KfGbMaT0L6zjeIu'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IfculRW2WXyzNQ8djX8WX'},
#       'href': 'https://api.spotify.com/v1/artists/7IfculRW2WXyzNQ8djX8WX',
#       'id': '7IfculRW2WXyzNQ8djX8WX',
#       'name': 'Erykah Badu',
#       'type': 'artist',
#       'uri': 'spotify:artist:7IfculRW2WXyzNQ8djX8WX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2gc9WOWqVRrGUENUjozcpY'},
#     'href': 'https://api.spotify.com/v1/albums/2gc9WOWqVRrGUENUjozcpY',
#     'id': '2gc9WOWqVRrGUENUjozcpY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273565896bfadad3e79bafed225',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02565896bfadad3e79bafed225',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851565896bfadad3e79bafed225',
#       'width': 64}],
#     'name': 'But You Caint Use My Phone (Mixtape)',
#     'release_date': '2015-11-27',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2gc9WOWqVRrGUENUjozcpY'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7IfculRW2WXyzNQ8djX8WX'},
#      'href': 'https://api.spotify.com/v1/artists/7IfculRW2WXyzNQ8djX8WX',
#      'id': '7IfculRW2WXyzNQ8djX8WX',
#      'name': 'Erykah Badu',
#      'type': 'artist',
#      'uri': 'spotify:artist:7IfculRW2WXyzNQ8djX8WX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 120053,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71518284'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1LljLapsjkl6sXsLwZzI73'},
#    'href': 'https://api.spotify.com/v1/tracks/1LljLapsjkl6sXsLwZzI73',
#    'id': '1LljLapsjkl6sXsLwZzI73',
#    'is_local': False,
#    'name': 'U Don’t Have To Call',
#    'popularity': 41,
#    'preview_url': 'https://p.scdn.co/mp3-preview/bca9b096c1e8e0d4cdd9dc2d222d8b77c4fea014?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:1LljLapsjkl6sXsLwZzI73'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12fRkVfO2fUsz1QHgDAG3g'},
#       'href': 'https://api.spotify.com/v1/artists/12fRkVfO2fUsz1QHgDAG3g',
#       'id': '12fRkVfO2fUsz1QHgDAG3g',
#       'name': 'Julia Jacklin',
#       'type': 'artist',
#       'uri': 'spotify:artist:12fRkVfO2fUsz1QHgDAG3g'}],
#     'available_markets': ['CR',
#      'DO',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'PA',
#      'SV',
#      'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/50G6NiGQgtYNiwNK018q8v'},
#     'href': 'https://api.spotify.com/v1/albums/50G6NiGQgtYNiwNK018q8v',
#     'id': '50G6NiGQgtYNiwNK018q8v',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e17d7a15cf864f9920271304',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e17d7a15cf864f9920271304',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e17d7a15cf864f9920271304',
#       'width': 64}],
#     'name': 'Crushing',
#     'release_date': '2019-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:50G6NiGQgtYNiwNK018q8v'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12fRkVfO2fUsz1QHgDAG3g'},
#      'href': 'https://api.spotify.com/v1/artists/12fRkVfO2fUsz1QHgDAG3g',
#      'id': '12fRkVfO2fUsz1QHgDAG3g',
#      'name': 'Julia Jacklin',
#      'type': 'artist',
#      'uri': 'spotify:artist:12fRkVfO2fUsz1QHgDAG3g'}],
#    'available_markets': ['CR', 'DO', 'GT', 'HN', 'MX', 'NI', 'PA', 'SV', 'US'],
#    'disc_number': 1,
#    'duration_ms': 307613,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKZV1800115'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2l7JlYeniNFfIzfj3dOUjb'},
#    'href': 'https://api.spotify.com/v1/tracks/2l7JlYeniNFfIzfj3dOUjb',
#    'id': '2l7JlYeniNFfIzfj3dOUjb',
#    'is_local': False,
#    'name': 'Body',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d39493eed6a431afeeba13e577f1ee1e19e41208?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2l7JlYeniNFfIzfj3dOUjb'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#       'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#       'id': '7tYKF4w9nC0nq9CsPZTHyP',
#       'name': 'SZA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/07w0rG5TETcyihsEIZR3qG'},
#     'href': 'https://api.spotify.com/v1/albums/07w0rG5TETcyihsEIZR3qG',
#     'id': '07w0rG5TETcyihsEIZR3qG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27370dbc9f47669d120ad874ec1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0270dbc9f47669d120ad874ec1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485170dbc9f47669d120ad874ec1',
#       'width': 64}],
#     'name': 'SOS',
#     'release_date': '2022-12-09',
#     'release_date_precision': 'day',
#     'total_tracks': 23,
#     'type': 'album',
#     'uri': 'spotify:album:07w0rG5TETcyihsEIZR3qG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#      'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#      'id': '7tYKF4w9nC0nq9CsPZTHyP',
#      'name': 'SZA',
#      'type': 'artist',
#      'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 153946,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC12204584'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3OHfY25tqY28d16oZczHc8'},
#    'href': 'https://api.spotify.com/v1/tracks/3OHfY25tqY28d16oZczHc8',
#    'id': '3OHfY25tqY28d16oZczHc8',
#    'is_local': False,
#    'name': 'Kill Bill',
#    'popularity': 92,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ac3426aecc4cc1fc7c3961aee6e6389c804f01b8?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3OHfY25tqY28d16oZczHc8'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TwOrUcYnAlIiKmVQkkoSZ'},
#       'href': 'https://api.spotify.com/v1/artists/2TwOrUcYnAlIiKmVQkkoSZ',
#       'id': '2TwOrUcYnAlIiKmVQkkoSZ',
#       'name': 'Wet Leg',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TwOrUcYnAlIiKmVQkkoSZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0r9awI5WRCZpwk0aVQ4bKO'},
#     'href': 'https://api.spotify.com/v1/albums/0r9awI5WRCZpwk0aVQ4bKO',
#     'id': '0r9awI5WRCZpwk0aVQ4bKO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ea1126a33b0fb88e79915262',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ea1126a33b0fb88e79915262',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ea1126a33b0fb88e79915262',
#       'width': 64}],
#     'name': 'Wet Leg',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0r9awI5WRCZpwk0aVQ4bKO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TwOrUcYnAlIiKmVQkkoSZ'},
#      'href': 'https://api.spotify.com/v1/artists/2TwOrUcYnAlIiKmVQkkoSZ',
#      'id': '2TwOrUcYnAlIiKmVQkkoSZ',
#      'name': 'Wet Leg',
#      'type': 'artist',
#      'uri': 'spotify:artist:2TwOrUcYnAlIiKmVQkkoSZ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 122466,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBCEL2100561'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4VBE0mwU8Nmm8hiqfCe4Ve'},
#    'href': 'https://api.spotify.com/v1/tracks/4VBE0mwU8Nmm8hiqfCe4Ve',
#    'id': '4VBE0mwU8Nmm8hiqfCe4Ve',
#    'is_local': False,
#    'name': 'Being In Love',
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a37ad9617c56201b3e20e6acf290b327610ae5e4?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4VBE0mwU8Nmm8hiqfCe4Ve'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#       'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#       'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#       'name': 'Mac DeMarco',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3oMrhnFjxkH6ccmXE4ltVn'},
#     'href': 'https://api.spotify.com/v1/albums/3oMrhnFjxkH6ccmXE4ltVn',
#     'id': '3oMrhnFjxkH6ccmXE4ltVn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27306bcba8c72327edfdf89583f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0206bcba8c72327edfdf89583f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485106bcba8c72327edfdf89583f',
#       'width': 64}],
#     'name': 'Old Dog Demos',
#     'release_date': '2018-04-21',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3oMrhnFjxkH6ccmXE4ltVn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#      'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#      'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#      'name': 'Mac DeMarco',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 216270,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMMZN1801592'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7z0BXwOUqDM7xAYp8Oa5zI'},
#    'href': 'https://api.spotify.com/v1/tracks/7z0BXwOUqDM7xAYp8Oa5zI',
#    'id': '7z0BXwOUqDM7xAYp8Oa5zI',
#    'is_local': False,
#    'name': 'No Sunny Days - Demo',
#    'popularity': 31,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fffbad3ffd1e72ca02782d37c4b044dcce86dcc1?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7z0BXwOUqDM7xAYp8Oa5zI'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dDqxbEKfPN3RZYrGr36y8'},
#       'href': 'https://api.spotify.com/v1/artists/4dDqxbEKfPN3RZYrGr36y8',
#       'id': '4dDqxbEKfPN3RZYrGr36y8',
#       'name': 'Fruition',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dDqxbEKfPN3RZYrGr36y8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/01IGPhxxdGyz8B3K9NXump'},
#     'href': 'https://api.spotify.com/v1/albums/01IGPhxxdGyz8B3K9NXump',
#     'id': '01IGPhxxdGyz8B3K9NXump',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ebbecf445e57b6c62c45d995',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ebbecf445e57b6c62c45d995',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ebbecf445e57b6c62c45d995',
#       'width': 64}],
#     'name': 'Just One of Them Nights',
#     'release_date': '2013-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:01IGPhxxdGyz8B3K9NXump'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dDqxbEKfPN3RZYrGr36y8'},
#      'href': 'https://api.spotify.com/v1/artists/4dDqxbEKfPN3RZYrGr36y8',
#      'id': '4dDqxbEKfPN3RZYrGr36y8',
#      'name': 'Fruition',
#      'type': 'artist',
#      'uri': 'spotify:artist:4dDqxbEKfPN3RZYrGr36y8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 238386,
#    'explicit': False,
#    'external_ids': {'isrc': 'USHM81322321'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4SFGLvwmkUukUezIJIKFEL'},
#    'href': 'https://api.spotify.com/v1/tracks/4SFGLvwmkUukUezIJIKFEL',
#    'id': '4SFGLvwmkUukUezIJIKFEL',
#    'is_local': False,
#    'name': 'Mountain Annie',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9be8c3caf5d5a7a121026bbcbf92fba4b7a19ffd?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4SFGLvwmkUukUezIJIKFEL'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TwOrUcYnAlIiKmVQkkoSZ'},
#       'href': 'https://api.spotify.com/v1/artists/2TwOrUcYnAlIiKmVQkkoSZ',
#       'id': '2TwOrUcYnAlIiKmVQkkoSZ',
#       'name': 'Wet Leg',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TwOrUcYnAlIiKmVQkkoSZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0r9awI5WRCZpwk0aVQ4bKO'},
#     'href': 'https://api.spotify.com/v1/albums/0r9awI5WRCZpwk0aVQ4bKO',
#     'id': '0r9awI5WRCZpwk0aVQ4bKO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ea1126a33b0fb88e79915262',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ea1126a33b0fb88e79915262',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ea1126a33b0fb88e79915262',
#       'width': 64}],
#     'name': 'Wet Leg',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0r9awI5WRCZpwk0aVQ4bKO'},
# ...
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 715615,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBJSH1520912'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/38IyNKqbuwGibICBVzbazp'},
#    'href': 'https://api.spotify.com/v1/tracks/38IyNKqbuwGibICBVzbazp',
#    'id': '38IyNKqbuwGibICBVzbazp',
#    'is_local': False,
#    'name': 'Compared To What',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/51b56d77474a871ee41b234aa734ae9d5935e3c0?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:38IyNKqbuwGibICBVzbazp'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#       'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#       'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#       'name': 'Mac DeMarco',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2sij95QgjmgrhNv33achzn'},
#     'href': 'https://api.spotify.com/v1/albums/2sij95QgjmgrhNv33achzn',
#     'id': '2sij95QgjmgrhNv33achzn',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ec6e9c13eeed14eedbd5f7c9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ec6e9c13eeed14eedbd5f7c9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ec6e9c13eeed14eedbd5f7c9',
#       'width': 64}],
#     'name': 'Salad Days',
#     'release_date': '2014-04-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2sij95QgjmgrhNv33achzn'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Sz7ZnJQBIHsXLUSo0OQtM'},
#      'href': 'https://api.spotify.com/v1/artists/3Sz7ZnJQBIHsXLUSo0OQtM',
#      'id': '3Sz7ZnJQBIHsXLUSo0OQtM',
#      'name': 'Mac DeMarco',
#      'type': 'artist',
#      'uri': 'spotify:artist:3Sz7ZnJQBIHsXLUSo0OQtM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 248171,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMMZN1300565'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4UeeEpl4omoe9T9U1ULVL4'},
#    'href': 'https://api.spotify.com/v1/tracks/4UeeEpl4omoe9T9U1ULVL4',
#    'id': '4UeeEpl4omoe9T9U1ULVL4',
#    'is_local': False,
#    'name': 'Let My Baby Stay',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d7b2423447e8f12669394dedd92d65a9a24bac14?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:4UeeEpl4omoe9T9U1ULVL4'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TwOrUcYnAlIiKmVQkkoSZ'},
#       'href': 'https://api.spotify.com/v1/artists/2TwOrUcYnAlIiKmVQkkoSZ',
#       'id': '2TwOrUcYnAlIiKmVQkkoSZ',
#       'name': 'Wet Leg',
#       'type': 'artist',
#       'uri': 'spotify:artist:2TwOrUcYnAlIiKmVQkkoSZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0r9awI5WRCZpwk0aVQ4bKO'},
#     'href': 'https://api.spotify.com/v1/albums/0r9awI5WRCZpwk0aVQ4bKO',
#     'id': '0r9awI5WRCZpwk0aVQ4bKO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ea1126a33b0fb88e79915262',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ea1126a33b0fb88e79915262',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ea1126a33b0fb88e79915262',
#       'width': 64}],
#     'name': 'Wet Leg',
#     'release_date': '2022-04-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0r9awI5WRCZpwk0aVQ4bKO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TwOrUcYnAlIiKmVQkkoSZ'},
#      'href': 'https://api.spotify.com/v1/artists/2TwOrUcYnAlIiKmVQkkoSZ',
#      'id': '2TwOrUcYnAlIiKmVQkkoSZ',
#      'name': 'Wet Leg',
#      'type': 'artist',
#      'uri': 'spotify:artist:2TwOrUcYnAlIiKmVQkkoSZ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 157893,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBCEL2100564'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2NFf0lo7aqNuilv6iahFLG'},
#    'href': 'https://api.spotify.com/v1/tracks/2NFf0lo7aqNuilv6iahFLG',
#    'id': '2NFf0lo7aqNuilv6iahFLG',
#    'is_local': False,
#    'name': 'Convincing',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0d14d58daf6b78dcfd46a1f1c61234c5b16b141d?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:2NFf0lo7aqNuilv6iahFLG'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#       'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#       'id': '3qUMmh5biaB5hqpF4LqS3m',
#       'name': 'Julie London',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0PXtSUifcfNg45o3FOEg31'},
#     'href': 'https://api.spotify.com/v1/albums/0PXtSUifcfNg45o3FOEg31',
#     'id': '0PXtSUifcfNg45o3FOEg31',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27362fe7a67cbbe41760eef88dd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0262fe7a67cbbe41760eef88dd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485162fe7a67cbbe41760eef88dd',
#       'width': 64}],
#     'name': 'Julie Is Her Name, Vol. 2',
#     'release_date': '1958',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0PXtSUifcfNg45o3FOEg31'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qUMmh5biaB5hqpF4LqS3m'},
#      'href': 'https://api.spotify.com/v1/artists/3qUMmh5biaB5hqpF4LqS3m',
#      'id': '3qUMmh5biaB5hqpF4LqS3m',
#      'name': 'Julie London',
#      'type': 'artist',
#      'uri': 'spotify:artist:3qUMmh5biaB5hqpF4LqS3m'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 153253,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA25800334'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5qfEAELRtcWyKjaheHHWQb'},
#    'href': 'https://api.spotify.com/v1/tracks/5qfEAELRtcWyKjaheHHWQb',
#    'id': '5qfEAELRtcWyKjaheHHWQb',
#    'is_local': False,
#    'name': 'Blue Moon',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a62d8f95b5dd110af50a4585606ad7270fd8295f?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5qfEAELRtcWyKjaheHHWQb'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6p2442ymrT9lZEuCZJdYcH'},
#       'href': 'https://api.spotify.com/v1/artists/6p2442ymrT9lZEuCZJdYcH',
#       'id': '6p2442ymrT9lZEuCZJdYcH',
#       'name': 'Ivy Queen',
#       'type': 'artist',
#       'uri': 'spotify:artist:6p2442ymrT9lZEuCZJdYcH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Sv18KP8WCk1eHGnhJqTrb'},
#     'href': 'https://api.spotify.com/v1/albums/0Sv18KP8WCk1eHGnhJqTrb',
#     'id': '0Sv18KP8WCk1eHGnhJqTrb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273774ca12732a1ae8541a45b5b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02774ca12732a1ae8541a45b5b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851774ca12732a1ae8541a45b5b',
#       'width': 64}],
#     'name': 'DIVA- Platinum Edition',
#     'release_date': '2004-01-27',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:0Sv18KP8WCk1eHGnhJqTrb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6p2442ymrT9lZEuCZJdYcH'},
#      'href': 'https://api.spotify.com/v1/artists/6p2442ymrT9lZEuCZJdYcH',
#      'id': '6p2442ymrT9lZEuCZJdYcH',
#      'name': 'Ivy Queen',
#      'type': 'artist',
#      'uri': 'spotify:artist:6p2442ymrT9lZEuCZJdYcH'}],
#    'available_markets': ['AD',
#     'AE',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KW',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'SA',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 186506,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG10300820'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7mY1dIaY9vY6Jrlrjg3dRn'},
#    'href': 'https://api.spotify.com/v1/tracks/7mY1dIaY9vY6Jrlrjg3dRn',
#    'id': '7mY1dIaY9vY6Jrlrjg3dRn',
#    'is_local': False,
#    'name': 'Quiero Bailar',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6ed5d2cfe2c68513b34e8dc4c2e55220a4dec5fe?cid=f90efb9e78574dd49b813de1efa3232d',
#    'track_number': 22,
#    'type': 'track',
#    'uri': 'spotify:track:7mY1dIaY9vY6Jrlrjg3dRn'}],
#  'total': 50,
#  'limit': 20,
#  'offset': 0,
#  'href': 'https://api.spotify.com/v1/me/top/tracks?time_range=short_term',
#  'next': 'https://api.spotify.com/v1/me/top/tracks?limit=20&offset=20&time_range=short_term',
#  'previous': None}

# %%
type(top_tracks_short)
# Out:
# dict

# %%
def get_track_ids(time_frame):
    track_ids = []
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
track_ids = get_track_ids(top_tracks_short)

# %%
track_ids
# Out:
# ['5Oc0vLGWdEWeCqIU8zyELt',
#  '7veyzFpXGgZj5Ul3TZ1lBc',
#  '3qurp3IMuJX3Ucr3OCDUg5',
#  '2fDkRzOciUWQPnIhW6CsHy',
#  '1cCbsojaA6GIT7Y3zuMJ1q',
#  '556jf0hyPQuLNHuNWo12I5',
#  '480rD34KfGbMaT0L6zjeIu',
#  '1LljLapsjkl6sXsLwZzI73',
#  '2l7JlYeniNFfIzfj3dOUjb',
#  '3OHfY25tqY28d16oZczHc8',
#  '4VBE0mwU8Nmm8hiqfCe4Ve',
#  '7z0BXwOUqDM7xAYp8Oa5zI',
#  '4SFGLvwmkUukUezIJIKFEL',
#  '260Ub1Yuj4CobdISTOBvM9',
#  '2JPlAh94PTtjZmCs2dY0P7',
#  '38IyNKqbuwGibICBVzbazp',
#  '4UeeEpl4omoe9T9U1ULVL4',
#  '2NFf0lo7aqNuilv6iahFLG',
#  '5qfEAELRtcWyKjaheHHWQb',
#  '7mY1dIaY9vY6Jrlrjg3dRn']

# %%
track_id = '3OHfY25tqY28d16oZczHc8'

# %%
def get_track_features(id):
    meta = sp.track(id)
    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    spotify_url = meta['external_urls']['spotify']
    album_cover = meta['album']['images'][0]['url']
    track_info = [name, album, artist, spotify_url, album_cover]
    return track_info

# %%
get_track_features(track_id)
# Out:
# ['Kill Bill',
#  'SOS',
#  'SZA',
#  'https://open.spotify.com/track/3OHfY25tqY28d16oZczHc8',
#  'https://i.scdn.co/image/ab67616d0000b27370dbc9f47669d120ad874ec1']

# %%
# loop over track ids 
tracks = []
for i in range(len(track_ids)):
    time.sleep(.5)
    track = get_track_features(track_ids[i])
    tracks.append(track)

# %%
tracks
# Out:
# [['Hound Dog',
#   "Ball n' Chain",
#   'Big Mama Thornton',
#   'https://open.spotify.com/track/5Oc0vLGWdEWeCqIU8zyELt',
#   'https://i.scdn.co/image/ab67616d0000b273f25345e400eb77c2d49f8558'],
#  ['Goodbye Weekend',
#   'Salad Days',
#   'Mac DeMarco',
#   'https://open.spotify.com/track/7veyzFpXGgZj5Ul3TZ1lBc',
#   'https://i.scdn.co/image/ab67616d0000b273ec6e9c13eeed14eedbd5f7c9'],
#  ['Is It Boy - Demo',
#   'Old Dog Demos',
#   'Mac DeMarco',
#   'https://open.spotify.com/track/3qurp3IMuJX3Ucr3OCDUg5',
#   'https://i.scdn.co/image/ab67616d0000b27306bcba8c72327edfdf89583f'],
#  ['Sweet Sugar Sweet',
#   'Laughing On The Outside',
#   'Bernadette Carroll',
#   'https://open.spotify.com/track/2fDkRzOciUWQPnIhW6CsHy',
#   'https://i.scdn.co/image/ab67616d0000b273d0c6e9667b128a9801e5e2c8'],
#  ['Nangs',
#   'Currents',
#   'Tame Impala',
#   'https://open.spotify.com/track/1cCbsojaA6GIT7Y3zuMJ1q',
#   'https://i.scdn.co/image/ab67616d0000b2739e1cfc756886ac782e363d79'],
#  ['Floated By',
#   'Bismillah',
#   'Peter Cat Recording Co.',
#   'https://open.spotify.com/track/556jf0hyPQuLNHuNWo12I5',
#   'https://i.scdn.co/image/ab67616d0000b27319497200ef054bccfab27d0c'],
#  ['Pressure To Party',
#   'Crushing',
#   'Julia Jacklin',
#   'https://open.spotify.com/track/480rD34KfGbMaT0L6zjeIu',
#   'https://i.scdn.co/image/ab67616d0000b273e17d7a15cf864f9920271304'],
#  ['U Don’t Have To Call',
#   'But You Caint Use My Phone (Mixtape)',
#   'Erykah Badu',
#   'https://open.spotify.com/track/1LljLapsjkl6sXsLwZzI73',
#   'https://i.scdn.co/image/ab67616d0000b273565896bfadad3e79bafed225'],
#  ['Body',
#   'Crushing',
#   'Julia Jacklin',
#   'https://open.spotify.com/track/2l7JlYeniNFfIzfj3dOUjb',
#   'https://i.scdn.co/image/ab67616d0000b273e17d7a15cf864f9920271304'],
#  ['Kill Bill',
#   'SOS',
#   'SZA',
#   'https://open.spotify.com/track/3OHfY25tqY28d16oZczHc8',
#   'https://i.scdn.co/image/ab67616d0000b27370dbc9f47669d120ad874ec1'],
#  ['Being In Love',
#   'Wet Leg',
#   'Wet Leg',
#   'https://open.spotify.com/track/4VBE0mwU8Nmm8hiqfCe4Ve',
#   'https://i.scdn.co/image/ab67616d0000b273ea1126a33b0fb88e79915262'],
#  ['No Sunny Days - Demo',
#   'Old Dog Demos',
#   'Mac DeMarco',
#   'https://open.spotify.com/track/7z0BXwOUqDM7xAYp8Oa5zI',
#   'https://i.scdn.co/image/ab67616d0000b27306bcba8c72327edfdf89583f'],
#  ['Mountain Annie',
#   'Just One of Them Nights',
#   'Fruition',
#   'https://open.spotify.com/track/4SFGLvwmkUukUezIJIKFEL',
#   'https://i.scdn.co/image/ab67616d0000b273ebbecf445e57b6c62c45d995'],
#  ['Wet Dream',
#   'Wet Leg',
#   'Wet Leg',
#   'https://open.spotify.com/track/260Ub1Yuj4CobdISTOBvM9',
#   'https://i.scdn.co/image/ab67616d0000b273ea1126a33b0fb88e79915262'],
#  ['Let Her Go',
#   'Salad Days',
#   'Mac DeMarco',
#   'https://open.spotify.com/track/2JPlAh94PTtjZmCs2dY0P7',
#   'https://i.scdn.co/image/ab67616d0000b273ec6e9c13eeed14eedbd5f7c9'],
#  ['Compared To What',
#   'Live in Los Angeles',
#   "Brian Auger's Oblivion Express",
#   'https://open.spotify.com/track/38IyNKqbuwGibICBVzbazp',
#   'https://i.scdn.co/image/ab67616d0000b273deba114fcd2da1fd4da5000d'],
#  ['Let My Baby Stay',
#   'Salad Days',
#   'Mac DeMarco',
#   'https://open.spotify.com/track/4UeeEpl4omoe9T9U1ULVL4',
#   'https://i.scdn.co/image/ab67616d0000b273ec6e9c13eeed14eedbd5f7c9'],
#  ['Convincing',
#   'Wet Leg',
#   'Wet Leg',
#   'https://open.spotify.com/track/2NFf0lo7aqNuilv6iahFLG',
#   'https://i.scdn.co/image/ab67616d0000b273ea1126a33b0fb88e79915262'],
#  ['Blue Moon',
#   'Julie Is Her Name, Vol. 2',
#   'Julie London',
#   'https://open.spotify.com/track/5qfEAELRtcWyKjaheHHWQb',
#   'https://i.scdn.co/image/ab67616d0000b27362fe7a67cbbe41760eef88dd'],
#  ['Quiero Bailar',
#   'DIVA- Platinum Edition',
#   'Ivy Queen',
#   'https://open.spotify.com/track/7mY1dIaY9vY6Jrlrjg3dRn',
#   'https://i.scdn.co/image/ab67616d0000b273774ca12732a1ae8541a45b5b']]

# %%
# create dataset
df = pd.DataFrame(tracks, columns = ["name", "album", "artist", "spotify_url", "album_cover"])
df.head(5)
# Out:
#                 name                    album              artist  \
# 0          Hound Dog            Ball n' Chain   Big Mama Thornton
# 1    Goodbye Weekend               Salad Days         Mac DeMarco
# 2   Is It Boy - Demo            Old Dog Demos         Mac DeMarco
# 3  Sweet Sugar Sweet  Laughing On The Outside  Bernadette Carroll
# 4              Nangs                 Currents         Tame Impala
#
#                                          spotify_url  \
# 0  https://open.spotify.com/track/5Oc0vLGWdEWeCqI...
# 1  https://open.spotify.com/track/7veyzFpXGgZj5Ul...
# 2  https://open.spotify.com/track/3qurp3IMuJX3Ucr...
# 3  https://open.spotify.com/track/2fDkRzOciUWQPnI...
# 4  https://open.spotify.com/track/1cCbsojaA6GIT7Y...
#
#                                          album_cover
# 0  https://i.scdn.co/image/ab67616d0000b273f25345...
# 1  https://i.scdn.co/image/ab67616d0000b273ec6e9c...
# 2  https://i.scdn.co/image/ab67616d0000b27306bcba...
# 3  https://i.scdn.co/image/ab67616d0000b273d0c6e9...
# 4  https://i.scdn.co/image/ab67616d0000b2739e1cfc...

# %%
gc = gspread.service_account(filename = "my-spotify-wrapped-test-377808-11876a84e4c1.json")

# %%
sh = gc.open("My Spotify Wrapped")

# %%
worksheet = sh.worksheet("short_term")

# %%
# worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# %%
# insert into sheet
def insert_to_gsheet(track_ids):
    # loop over track ids 
    tracks = []
    for i in range(len(track_ids)):
        time.sleep(.5)
        track = get_track_features(track_ids[i])
        tracks.append(track)
    # create dataframe
    df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'spotify_url', 'album_cover'])
    # insert into google sheet
    gc = gspread.service_account(filename='my-spotify-wrapped-test-377808-11876a84e4c1.json')
    sh = gc.open('My Spotify Wrapped')
    worksheet = sh.worksheet(f'{time_period}')
    worksheet.update([df.columns.values.tolist()] + df.values.tolist())
    print('Done')

# %%
time_ranges = ['short_term', 'medium_term', 'long_term']
for time_period in time_ranges:
    top_tracks = sp.current_user_top_tracks(limit=20, offset=0, time_range=time_period)
    track_ids = get_track_ids(top_tracks)
    insert_to_gsheet(track_ids)
# Out:
# Done
# Done
# Done
